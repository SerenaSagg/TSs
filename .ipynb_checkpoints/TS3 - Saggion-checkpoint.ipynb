# %% [markdown]
# # TS3: Análisis de Fourier: FFT, desparramo, interpolación y ventaneo
#
# ## Introducción teórica
#
# El análisis de Fourier permite descomponer una señal en sus componentes frecuenciales. En el caso discreto, la herramienta utilizada es la Transformada Discreta de Fourier (DFT), definida como:
#
# $$
# X[w] = \sum_{n=0}^{N-1} x[n] \, e^{-jwn}
# $$
#
# donde x[n] es la señal temporal de longitud N, y X[w] son los coeficientes espectrales que describen amplitud y fase en frecuencias discretas.
#
# ### Densidad Espectral de Potencia (PSD)
#
# La Densidad Espectral de Potencia (PSD) describe cómo se distribuye la potencia de una señal en función de la frecuencia. A partir de la DFT puede estimarse como:
#
# $$
# P[k] = \frac{1}{N} \, \left| X[k] \right|^2 , \quad k=0,1,\dots,N-1
# $$
#
#
# Esta relación permite analizar la potencia de la señal en cada componente frecuencial y se emplea extensamente en aplicaciones de comunicaciones, acústica y control.
#
# ### Desparramo espectral
#
# El desparramo espectral ocurre cuando la frecuencia de la señal no coincide con un múltiplo entero de la resolución en frecuencia:
#
# $$
# \Delta f = \frac{f_s}{N}
# $$
#
# En este caso, la energía de la señal no queda confinada a un único bin espectral, sino que se dispersa entre varios, generando lóbulos laterales y dificultando la identificación precisa de frecuencias.
#
# ### Identidad de Parseval
#
# La identidad de Parseval establece que la energía de la señal en el dominio del tiempo es equivalente a la energía en el dominio de la frecuencia:
#
# $$
# \sum_{n=0}^{N-1} |x[n]|^2 \;=\; \frac{1}{N} \sum_{k=0}^{N-1} |X[k]|^2
# $$
#
# Este principio es esencial para verificar la consistencia de la representación espectral y comprobar que la PSD refleja fielmente la potencia de la señal original.
# ### Zero Padding
#
# La técnica de zero padding consiste en añadir ceros al final de la señal antes de calcular la DFT. Si bien este procedimiento no modifica el contenido de la señal ni aumenta la información disponible, sí genera una malla más densa en el eje frecuencial. Esto permite observar con mayor detalle la forma del espectro y facilita la localización precisa de picos de potencia en la PSD, mejorando así la interpretación de los resultados.

# %% [markdown]
# ## Desarrollo y Análisis

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.fft import fft

N=200
fs=N
df=fs/N
Ts=1/fs

def sen(f,n,A=1,fase=0,fs=2):
    N=np.arange(n)
    t=N/fs
    x=A*np.sin(2*np.pi*f*t+fase)
    return t,x

t1,x1=sen(f=(N/4)*df,n=N,fs=fs)
t2,x2=sen(f=((N/4)+0.25)*df,n=N,fs=fs)
t2,x3=sen(f=((N/4)+0.5)*df,n=N,fs=fs)

X1=fft(x1)
X2=fft(x2)
X3=fft(x3)


PSD1 = (np.abs(X1)**2)/N
PSD2 = (np.abs(X2)**2)/N
PSD3 = (np.abs(X3)**2)/N


F=np.arange(N)*df

plt.figure(figsize=(8,5))
plt.plot(F, PSD1,"x", label="k0 = N/4")
plt.plot(F, PSD2,"x", label="k0 = N/4+0.25")
plt.plot(F, PSD3,"x", label="k0 = N/4+0.5")
plt.legend()
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("PDS")
plt.title("Densidades espectrales de potencia")
plt.grid(True)
plt.xlim([0, fs/2])  
plt.show()

# %% [markdown]
# Se puede observar que, a pesar de que la diferencia entre las frecuencias analizadas es mínima, el efecto en el dominio espectral es notoriamente distinto. En el caso de k=N/4 la frecuencia coincide exactamente con un múltiplo entero de la resolución espectral Δf, por lo que la energía se concentra en un único bin y no aparece desparramo. En cambio, para las señales restantes la pequeña desintonía respecto de
# Δf provoca un ensanchamiento del lóbulo principal y una disminución de la amplitud máxima observada en el espectro. Se genere el efecto desparramo espectral.

# %%
# dominio del tiempo
P_t1 = np.mean(x1**2)
P_t2 = np.mean(x2**2)
P_t3 = np.mean(x3**2)

#  dominio de la frecuencia (Parseval)
P_f1 = np.sum(PSD1)/N
P_f2 = np.sum(PSD2)/N
P_f3 = np.sum(PSD3)/N

print("Señal k0 = N/4:     Potencia tiempo = %.6f,  Parseval = %.6f" % (P_t1, P_f1))
print("Señal k0 = N/4+0.25: Potencia tiempo = %.6f,  Parseval = %.6f" % (P_t2, P_f2))
print("Señal k0 = N/4+0.5:  Potencia tiempo = %.6f,  Parseval = %.6f" % (P_t3, P_f3))
# Out:
# Señal k0 = N/4:     Potencia tiempo = 0.500000,  Parseval = 0.500000
# Señal k0 = N/4+0.25: Potencia tiempo = 0.497500,  Parseval = 0.497500
# Señal k0 = N/4+0.5:  Potencia tiempo = 0.500000,  Parseval = 0.500000

# %% [markdown]
# Mediante el teorema de Parseval se confirma que todas las señales poseen la misma energía total. En el gráfico se aprecia cómo dicha energía se distribuye entre los distintos bins de la transformada, aunque las áreas totales bajo la curva son iguales.

# %%
Nz = 9 * N   
df=fs/Nz

X1z = fft(x1, n=Nz)   
X2z = fft(x2, n=Nz)
X3z = fft(x3, n=Nz)

PSD1z = (np.abs(X1z)**2)/N  
PSD2z = (np.abs(X2z)**2)/N
PSD3z = (np.abs(X3z)**2)/N

F=np.arange(Nz)*df

plt.plot(F, PSD1z,"x", label="k0 = N/4")
plt.plot(F, PSD2z,"x", label="k0 = N/4+0.25")
plt.plot(F, PSD3z,"x", label="k0 = N/4+0.5")
plt.legend()
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("PDS ")
plt.title("Densidades espectrales de potencia (con zero padding)")
plt.grid(True)
plt.xlim([0, fs/2])
plt.show()

# %% [markdown]
# Al aplicar zero padding se incrementa la cantidad de puntos de muestreo, mejorando la interpolación del espectro. Esto permite distinguir con mayor claridad tanto el lóbulo principal como los lóbulos secundarios de la transformada.

# %% [markdown]
# ## Conclusión
#
# A partir de esta tarea se corrobora que una mínima variación en la frecuencia de una señal puede modificar significativamente la forma en que se distribuye su energía en el dominio espectral. Cuando la frecuencia coincide exactamente con un bin de la transformada, la energía se concentra en ese único componente. En cambio, cuando existe una ligera desintonía, la energía se reparte entre bins vecinos, generando el efecto de desparramo espectral.
#
# Finalmente, mediante la técnica de zero padding es posible incrementar la cantidad de puntos de muestreo en frecuencia, lo que brinda una interpolación mas suave, una representación más detallada del espectro y permite visualizar con mayor claridad tanto el lóbulo principal como los secundarios, sin alterar la energía total ni la resolución espectral real.
#
# ## Autoevaluación
#
# Resolví la tarea con seguridad.
#
# Aclare las dudas que tenia sobre la transformada de fourier y como aplicarla a nivel práctico. Aprendi como la variación de la frecuencia puede llegar a afectar sobre la distribución de su energia, y como mejorar la muestra de un espectro.
#
# Utilice ChatGPT para optimizar detalles del codigo.
